# %% [markdown]
# # Homework Buổi 7 - Pandas và hồi quy

# %% [markdown]
# ## Bài 1
# Tạo DataFrame từ dictionary của đề; in 3 dòng đầu, dòng 1-2 bằng `iloc`, và thống kê population.

# %%
import pandas as pd
data = {"cities": ["Glasgow", "Edinburgh", "Aberdeen", "Dundee", "Hanoi"], "gdp": [50, 40, 30, 25, 60], "population": [54490, 16940, 44950, 24260, 34560], "year": [2013] * 5}
# Viết code tại đây

# %% [markdown]
# ## Bài 2
# Tính correlation giữa `population` và `gdp`, sau đó fit hồi quy tuyến tính và in coefficient, intercept, R-square.
#
# ## Bài 3 - Đọc CSV
# Tạo hoặc đặt file `cities.csv` trong cùng thư mục notebook, sau đó dùng `pd.read_csv` để đọc thành DataFrame và in 3 dòng đầu.
#
# ## Bài 4 - Đọc SQL
# Dùng SQLite và `pd.read_sql_query` để đọc bảng `cities` từ file `cities.db`. Nếu chưa có database, chỉ cần viết đúng đoạn kết nối và câu lệnh đọc.

# %%
# Bài 2: correlation và hồi quy

# Bài 3: đọc cities.csv
# df_csv = pd.read_csv("cities.csv")
# print(df_csv.head(3))

# Bài 4: đọc cities.db bằng SQLite
# import sqlite3
# connection = sqlite3.connect("cities.db")
# df_sql = pd.read_sql_query("SELECT * FROM cities", connection)
# connection.close()
# print(df_sql.head(3))
