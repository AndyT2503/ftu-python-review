# %% [markdown]
# # Homework Buổi 2 - Điều kiện

# %% [markdown]
# ## Bài 1
# Nhập a, b, c và giải phương trình `ax + b = c`, xử lý đủ ba trường hợp của `a`.

# %%
# Viết code tại đây

# %% [markdown]
# ## Bài 2
# Nhập điểm 0-10 và xếp loại: `Excellent` từ 8.5, `Good` từ 7, `Pass` từ 5; báo lỗi nếu ngoài khoảng.

# %%
score = float(input("Score: "))
# Gợi ý: kiểm tra 0 <= score <= 10 trước, sau đó dùng if/elif/else
# Viết code tại đây
