# %% [markdown]
# # Homework Buổi 1 - Nhập liệu và tính toán
# Tự viết code trong các ô bên dưới. Không dùng giá trị hard-code thay cho input.

# %% [markdown]
# ## Bài 1
# Nhập chiều dài và chiều rộng, tính chu vi và diện tích hình chữ nhật.

# %%
# Viết code tại đây

# %% [markdown]
# ## Bài 2
# Nhập ngày thi dạng `dd/mm/yyyy`, tính số ngày còn lại từ hôm nay bằng `datetime`. Đây là bài luyện đúng phần ngày giờ đã học.

# %%
from datetime import datetime, date

text = input("Exam date (dd/mm/yyyy): ")
# Viết code tại đây: dùng datetime.strptime và tính số ngày còn lại
