# %% [markdown]
# # Homework Buổi 4 - Chuỗi

# %% [markdown]
# ## Bài 1
# Nhập một câu. Chuẩn hóa khoảng trắng và chữ thường, in số từ, từ dài nhất và số lần xuất hiện của từ dài nhất.

# %%
text = input("Sentence: ")
# Gợi ý: dùng strip(), split(), lower(), len() và max(..., key=len)
# Viết code tại đây

# %% [markdown]
# ## Bài 2
# Nhập một chuỗi và kiểm tra chuỗi đối xứng sau khi bỏ khoảng trắng, dấu chấm và dấu phẩy, không phân biệt chữ hoa/chữ thường.

# %%
text = input("Text: ")
# Gợi ý: dùng lower(), replace(), split(), join() và [::-1]
# Viết code tại đây

# %% [markdown]
# ## Bài 3
# Với một câu nhập từ bàn phím, tách các từ và tạo dictionary lưu mỗi từ cùng độ dài của từ đó. In dictionary kết quả.

# %%
text = input("Sentence: ")
# Gợi ý: chuẩn hóa bằng split(), tạo dictionary bằng dict và duyệt words bằng for
# Viết code tại đây
