# %% [markdown]
# # Homework Buổi 5 - List và dictionary

# %% [markdown]
# ## Bài 1
# Tạo list `scores` gồm 6 điểm. Thêm một điểm, xóa một điểm, rồi in số phần tử, điểm trung bình, nhỏ nhất và lớn nhất.

# %%
scores = [7.5, 8.0, 6.5, 9.0, 7.0, 8.5]
# Gợi ý: dùng append(), remove(), len(), sum(), min() và max()
# Viết code tại đây

# %% [markdown]
# ## Bài 2
# Tạo dictionary `student` từ ba list `keys` và `values`. Sau đó cập nhật tuổi, thêm điểm, dùng `get()` để đọc email chưa tồn tại và in dictionary.

# %%
keys = ["name", "age", "city"]
values = ["Lan", 20, "Hanoi"]
# Gợi ý: dùng dict(zip(keys, values)), cập nhật key và student.get(...)
# Viết code tại đây
