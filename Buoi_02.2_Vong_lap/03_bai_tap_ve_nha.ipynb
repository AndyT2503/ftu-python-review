# %% [markdown]
# # Homework Buổi 3 - Vòng lặp

# %% [markdown]
# ## Bài 1
# Dùng `for` tính tổng các số chia hết cho 3 từ 1 đến 100.

# %%
# Viết code tại đây

# %% [markdown]
# ## Bài 2
# Với list numbers, đếm số dương, số âm và số 0.

# %%
numbers = [2, -3, 0, 4, -1, 8, 0]
# Viết code tại đây
