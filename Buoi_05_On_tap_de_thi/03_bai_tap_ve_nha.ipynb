# %% [markdown]
# # Homework Buổi 8 - Tự luyện đề

# %% [markdown]
# Làm lại toàn bộ 6 câu trong `cuoiki.txt` trong 90 phút. Mỗi câu đặt trong một ô code riêng và không mở file đáp án khi làm.

# %%
# Câu 1

# %%
# Câu 2

# %%
# Câu 3-5

# %%
# Câu 6 - Pandas va hoi quy

# %% [markdown]
# ## Tự đánh giá
# Ghi lại câu làm sai, lỗi gặp phải và kiến thức cần ôn thêm.

# %%
# Ghi chú của em
