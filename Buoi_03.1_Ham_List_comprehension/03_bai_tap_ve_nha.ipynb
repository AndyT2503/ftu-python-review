# %% [markdown]
# # Homework Buổi 6 - List comprehension

# %% [markdown]
# ## Bài 1
# Tạo `python_list` gồm số nguyên từ 1 đến 200 bằng list comprehension; kiểm tra 137, 200 và 202.

# %%
# Viết code tại đây: dùng range(1, 201) và list comprehension

# %% [markdown]
# ## Bài 2
# Viết hàm `square(number)`, sau đó tạo list bình phương các số chẵn chia hết cho 3 từ 1 đến 100 bằng list comprehension.

# %%
# Viết code tại đây: kết hợp hàm, range(), điều kiện và list comprehension
